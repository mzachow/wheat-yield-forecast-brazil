# %%
"""Libraries"""
import glob
import random
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from scipy import signal
from sklearn.linear_model import LinearRegression, Ridge
from IPython.core.interactiveshell import InteractiveShell

"""Notebook Settings"""
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("error")
pd.set_option('display.max_columns', 500)
InteractiveShell.ast_node_interactivity = "all"
# %load_ext autoreload
# %autoreload 2

# %%
ha = pd.read_excel("Data/Wheat/ibge_trigo_harvested_area_9016.xlsx")
yi = pd.read_excel("Data/Wheat/ibge_trigo_safra.xlsx")

# %%
def read_train_yield():
    all_files = glob.glob("Data/Yield/WS/*.csv")
    recalculate_dict = {1: 2582.97, 2:2635.13, 3:2495.92, 4:2980.292} 
    li = []
    for filename in all_files:
        df2 = pd.read_csv(filename, encoding="latin-1")
        #print(df2)
        li.append(df2)

    df2 = pd.concat(li, axis=0, ignore_index=False)
    #print(df2)
    #df = df[df["Year"] <= 2019].groupby(["State", "Year"]).agg({"Yield":"mean"}).reset_index(drop=False).rename({"State":"zone", "Year":"year", "Yield":"yield"}, axis=1)
    #df2["Yield"] = df2.apply(lambda x: (x["Yield"]+1)*recalculate_dict[x["State"]], axis=1)
    return df2

relevant_municipalities = read_train_yield()["Nivel"].dropna().unique().tolist()
municipality_to_group = read_train_yield()[["Nivel", "State"]].groupby("Nivel")["State"].apply(lambda x: x.tolist()[0]).to_dict()
relevant_municipalities = [str(int(m)) for m in relevant_municipalities]

# %%
ha = (ha
 .loc[ha["Cod"].isin(relevant_municipalities)]
 .reset_index(drop=True)
 .replace(["-", "..."], np.nan))
yi = (yi
 .loc[yi["Cod"].isin(relevant_municipalities)]
 .reset_index(drop=True)
 .replace(["-", "..."], np.nan))

# %%
yi
# Out:
#          Cod                   Area    1993    1994    1995    1996    1997  \
# 0    4200101      Abelardo Luz (SC)  1200.0  1500.0  1500.0  1620.0  1300.0
# 1    4300059        Água Santa (RS)  1200.0  1200.0  1200.0  2400.0  1080.0
# 2    4200507  Águas de Chapecó (SC)  1080.0  1080.0  1200.0   722.0   714.0
# 3    4200556       Águas Frias (SC)   720.0   483.0   725.0   480.0   500.0
# 4    4300208         Ajuricaba (RS)  1700.0  1200.0  1000.0  1700.0  1500.0
# ..       ...                    ...     ...     ...     ...     ...     ...
# 579  4128708          Vitorino (PR)  1322.0  1646.0  1672.0  2085.0  1803.0
# 580  4128500    Wenceslau Braz (PR)  1800.0  1600.0     NaN     NaN     NaN
# 581  4219507           Xanxerê (SC)   960.0  1632.0  1500.0  1800.0  1200.0
# 582  4219705             Xaxim (SC)   720.0   720.0  1440.0   900.0   420.0
# 583  4219853            Zortéa (SC)     NaN     NaN     NaN     NaN  1000.0
#
# ...

# %%
yi = yi.set_index(["Cod", "Area"]).interpolate(method='linear', limit_direction='both', axis=1)
ha = ha.set_index(["Cod", "Nivel"]).interpolate(method='linear', limit_direction='both', axis=1)

# %%
yi = yi.reset_index(drop=False)
ha = ha.reset_index(drop=False)

# %%
yi["zone"] = yi["Cod"].apply(lambda x: municipality_to_group[int(x)])
ha["zone"] = ha["Cod"].apply(lambda x: municipality_to_group[int(x)])

# %%
yi = yi.drop(columns=["Area"])
ha = ha.drop(columns=["Nivel"])

# %%
yi = yi.loc[:, ['Cod', 'zone', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
       '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
       '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
       '2019']].sort_values(by="Cod").reset_index(drop=True)

# %%
ha_yi = ha.loc[:, ['Cod', 'zone', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
       '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
       '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
       '2019']].sort_values(by="Cod").reset_index(drop=True)

# %%
yi = yi.set_index(["Cod", "zone"]) * ha_yi.set_index(["Cod", "zone"])

# %%
yi_national = yi.sum() / ha_yi.sum()

# %%
yi_national = pd.DataFrame(yi_national).transpose()

# %%
yi_national = yi_national.stack().reset_index().drop(columns=["level_0"]).rename({"level_1":"year", 0:"yield"}, axis=1)
yi_national = yi_national.loc[yi_national["year"].astype(int) < 2017, :].copy().reset_index(drop=True)

# %%
yi_national
# Out:
#     year        yield
# 0   1993  1494.529554
# 1   1994  1596.135346
# 2   1995  1572.085081
# 3   1996  1870.445086
# 4   1997  1626.103873
# 5   1998  1600.905053
# 6   1999  1972.587575
# 7   2000  1550.645193
# 8   2001  1945.059152
# 9   2002  1480.932058
# 10  2003  2416.983877
# 11  2004  2063.965218
# 12  2005  1954.718434
# 13  2006   1537.19591
# 14  2007   2205.29465
# 15  2008  2558.629278
# 16  2009  2049.890354
# 17  2010  2852.412796
# 18  2011  2672.058841
# 19  2012  2271.883662
# 20  2013  2764.049042
# 21  2014  2144.009327
# 22  2015  2149.874984
# 23  2016  3167.872589

# %%
yi = yi.reset_index().groupby("zone").sum() / ha_yi.groupby("zone").sum()

# %%
yi = yi.stack().reset_index().rename({"level_1":"year", 0:"yield"}, axis=1

# %%
yi["zone"] = yi["zone"].astype(int)

# %%
yi = yi.sort_values(["zone", "year"]).reset_index(drop=True)

# %%
yi = yi.loc[yi["year"].astype(int) < 2017].reset_index(drop=True)

# %%
yi["year"]
# Out:
# 0     1993
# 1     1994
# 2     1995
# 3     1996
# 4     1997
#       ...
# 91    2012
# 92    2013
# 93    2014
# 94    2015
# 95    2016
# Name: year, Length: 96, dtype: int32

# %%
def read_and_detrend_yield_by_group(df):
    df = df.copy()
    li = []
    for group in [1, 2, 3, 4]:
        cv_yield = df.loc[(df["zone"] == group) & (df["year"].astype(int).isin(list(range(1993,2017))))].copy().reset_index(drop=True)
        reg = LinearRegression()
        slope_cv = reg.fit(cv_yield["year"].values.reshape(-1,1), cv_yield["yield"]).coef_[0]
        
        cv_yield["yield_detrended"] = cv_yield["yield"] + (slope_cv * (2016 - cv_yield["year"].astype(int)))
        li.append(cv_yield)

    df_cv = (pd
             .concat(li, axis=0, ignore_index=False)
             .sort_values(by=["zone", "year"])
             .reset_index(drop=True)
             .drop(["yield"], axis=1)
             .rename(columns={"yield_detrended":"yield"}))
        
    return df_cv

# %%
yi_detrended = read_and_detrend_yield_by_group(yi)

# %%
reg = LinearRegression()
slope_cv = reg.fit(yi_national["year"].values.reshape(-1,1), yi_national["yield"]).coef_[0]
        
yi_national["yield_detrended"] = yi_national["yield"] + (slope_cv * (2016 - yi_national["year"].astype(int)))

# %%
yi_national = yi_national.drop(["yield"], axis=1).rename(columns={"yield_detrended":"yield"})

# %%
yi_national.to_csv("national_yield.csv", index=False)

# %%
yi_detrended.to_csv("group_yield.csv", index=False)

# %%
yield_df['relative_harvested_area'] = yield_df['yield'] / yield_df.groupby('year')['yield'].transform('sum')

# %%
yield_df.year.unique()
# Out:
# array(['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019'], dtype=object)

# %%
yield_df
# Out:
#      zone  year      yield  relative_harvested_area
# 0       1  1990  1009412.0                 0.435808
# 1       1  1991   674580.0                 0.352521
# 2       1  1992   559010.0                 0.306202
# 3       1  1993   588855.0                 0.428271
# 4       1  1994   548362.0                 0.433166
# ..    ...   ...        ...                      ...
# 115     4  2015   370442.0                 0.170839
# 116     4  2016   301733.0                 0.161703
# 117     4  2017   253236.0                 0.155748
# 118     4  2018   284096.0                 0.158006
# 119     4  2019   277153.0                 0.155630
#
# [120 rows x 4 columns]

# %%
yield_df = yield_df.loc[yield_df["year"].astype(int) < 2017].groupby(["year", "zone"])["relative_harvested_area"].mean().reset_index()

# %%
yield_df["rolling_avg"] = yield_df.groupby('zone')['relative_harvested_area'].transform(lambda x: x.rolling(window=2, min_periods=2, closed='left').mean())

# %%
yield_df = yield_df.loc[yield_df["year"].astype(int) >= 1993].reset_index(drop=True)

# %%
yield_df
# Out:
#     year zone  relative_harvested_area  rolling_avg
# 0   1993    1                 0.428271     0.329361
# 1   1993    2                 0.184797     0.186511
# 2   1993    3                 0.255400     0.374454
# 3   1993    4                 0.131532     0.109674
# 4   1994    1                 0.433166     0.367237
# ..   ...  ...                      ...          ...
# 91  2015    4                 0.170839     0.191991
# 92  2016    1                 0.356043     0.372418
# 93  2016    2                 0.230919     0.220679
# 94  2016    3                 0.251336     0.230579
# 95  2016    4                 0.161703     0.176325
#
# [96 rows x 4 columns]

# %%
yield_df.to_csv("Data/Yield/harvested_area_by_group2.csv", index=False)

# %%
ha_group = ha.groupby("zone").sum()

# %%
ha_group
# Out:
#            1990           1991           1992       1993      1994  \
# zone
# 1     1009412.0  674580.000000  559010.000000  588855.00  548362.0
# 2      418792.0  325053.666667  370885.333333  254088.00  194809.0
# 3      584082.0  702938.916667  696597.833333  351163.75  360175.0
# 4      303897.0  211016.000000  199132.000000  180850.50  162593.0
#
#                1995           1996           1997           1998  \
# zone
# 1     292653.428571  568611.357143  465530.285714  370016.714286
# 2     249371.000000  353159.000000  301718.000000  325706.666667
# 3     316611.750000  576116.000000  528487.750000  505542.500000
# 4     113335.000000  217577.000000  152478.000000  132301.666667
#
#                1999           2000      2001      2002      2003      2004  \
# zone
# 1     393219.142857  535254.571429  551854.0  716900.0  942931.0  989220.0
# 2     302703.333333  242347.000000  350965.0  434224.0  510693.0  565967.0
# ...

# %%
sum_ = 0
for group in [1, 2, 3, 4]:
    mean_ = ha_group.loc[group].values.mean()
    sum_group = 0
    for i in range(3, 27):
        sum_group += abs(ha_group.loc[group].values[i-1] - ha_group.loc[group].values[i])
        #print(ha_group.loc[group].values[i-3:i-1].mean())
        #print(ha_group.loc[group].values[i])
    sum_group /= 24
    sum_ += sum_group
sum_ /= 4
print(sum_)
# Out:
# 90197.9089781746

# %% [markdown]
# three previous years = 112267
# two previous years = 107154
# previous year = 90197

# %%
ha_group = ha_group.stack().reset_index().rename({"level_1":"year", 0:"harvested_area"}, axis=1)

# %%
ha_group["adjusted"] = ha_group["harvested_area"].shift(1)

# %%
ha_group = ha_group.loc[ha_group["year"].astype(int).isin(list(range(1993,2017))), ["zone", "year", "adjusted"]].rename({"adjusted":"ha"}, axis=1).reset_index(drop=True)

# %%
ha_group
# Out:
#     zone  year             ha
# 0      1  1993  559010.000000
# 1      1  1994  588855.000000
# 2      1  1995  548362.000000
# 3      1  1996  292653.428571
# 4      1  1997  568611.357143
# ..   ...   ...            ...
# 91     4  2012  326772.000000
# 92     4  2013  303326.000000
# 93     4  2014  390475.000000
# 94     4  2015  462488.000000
# 95     4  2016  370442.000000
#
# [96 rows x 3 columns]

# %%
ha_group['ha'] = ha_group['ha'] / ha_group.groupby('year')['ha'].transform('sum')

# %%
ha_group["year"] = ha_group["year"].astype(int)

# %%
ha_group.to_csv("harvested_area.csv", index=False)

# %%
sns.lineplot(data=ha_group, x="year", y="ha", hue="zone")
# Out:
# <AxesSubplot:xlabel='year', ylabel='ha'>

# %%
df = pd.read_csv("Data/Yield/harvested_area_by_group2.csv")

# %%
df.head()
# Out:
#    year  zone  relative_harvested_area  rolling_avg
# 0  1993     1                 0.428271     0.329361
# 1  1993     2                 0.184797     0.186511
# 2  1993     3                 0.255400     0.374454
# 3  1993     4                 0.131532     0.109674
# 4  1994     1                 0.433166     0.367237

# %%
sns.lineplot(data=df, x="year", y="rolling_avg", hue="zone")
# Out:
# <AxesSubplot:xlabel='year', ylabel='rolling_avg'>

# %%
sns.lineplot(data=df, x="year", y="rolling_avg", hue="zone")
# Out:
# <AxesSubplot:xlabel='year', ylabel='relative_harvested_area'>
